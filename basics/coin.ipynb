# %%
from coin_flip import coin_flip

# %%
coin_flip.coin_flip(2,10000)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
random_data = np.random.randint(1,7,60000)
# parint(random_data)
print('mean',random_data.mean())
print('std',random_data.std())
plt.hist(random_data, bins=50, normed=0)
plt.show()
# Out:
# mean 3.5049166666666665
# std 1.7100611567199056
# /tmp/ipykernel_2853/3228225056.py:5: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   plt.hist(random_data, bins=50, normed=0)

# %%
sample_100 = []
for i in range(0,100):
    sample_100.append(random_data[int(np.random.random()*len(random_data))])
# print(sample_100)
print('mean',np.mean(sample_100))
print('std',np.std(sample_100, ddof= 1))
# Out:
# mean 3.68
# std 1.7048949136725895

# %%
sample_100_mean =[]
for i in range(0, 500):
    sample =[]
    for j in range(0,100):
        sample.append(random_data[int(np.random.random()*len(random_data))])
        sample_100_mean.append(np.mean(sample))
        sample_many_mean = np.mean(sample_100_mean)
plt.hist(sample_100_mean, bins=200, density=0)
plt.show()
